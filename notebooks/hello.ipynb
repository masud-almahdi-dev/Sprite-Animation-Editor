# %%
import pygame
class Button:
    page = 1
    color = [0,0,0]
    rect = [0,0,10,10]
    roundness = 8
    draw = True
    def __init__(self,rect,border_radius=8,color=[0,0,0],page=1):
        self.rect = rect
        self.color = color
        self.page = page
    def draw(self,scr):
        pygame.draw.rect(scr,self.color,self.rect,border_radius=self.roundness)

def start():
    pygame.init()
    AppTitle = "Hello Window"
    screen = pygame.display.set_mode((1080,720))
    pygame.display.set_caption(AppTitle)
    clock = pygame.time.Clock()
    running = True
    clearCOLOR = (0x00,0x09,0x0B)
    currentPage = 1
    buttons = []
    buttons.append(Button((113,89,152,152),8,[0x00,0x5E,0x70]))
    
    buttons.append(Button((272,89,154,45),8,[0x00,0x5E,0x70]))
    buttons.append(Button((272,142,154,46),8,[0x00,0x5E,0x70]))
    buttons.append(Button((272,196,154,45),8,[0x00,0x5E,0x70]))

    buttons.append(Button((114,300,152,51),8,[0x00,0x5E,0x70]))
    buttons.append(Button((113,359,152,51),8,[0x00,0x5E,0x70]))
    buttons.append(Button((113,418,152,51),8,[0x00,0x5E,0x70]))

    buttons.append(Button((272,300,152,51),8,[0x00,0x5E,0x70]))
    buttons.append(Button((272,359,152,51),8,[0x00,0x5E,0x70]))
    buttons.append(Button((272,418,152,51),8,[0x00,0x5E,0x70]))

    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT or (event.type == pygame.KEYDOWN and event.key == pygame.K_ESCAPE):
                running = False
        screen.fill(clearCOLOR)

        if currentPage == 1:
            pygame.draw.rect(screen,(0x01,0x26,0x2E),(0,0,540,557))
            pygame.draw.rect(screen,(0x00,0x1f,0x25),(0,557,1080,163))
        
        for x in buttons:
            if x.page == currentPage:
                x.draw(screen)
            


        pygame.display.update()
        clock.tick(60)
    pygame.quit()

start()
